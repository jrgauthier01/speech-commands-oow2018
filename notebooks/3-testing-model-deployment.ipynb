# %% [markdown]
# ![banner](https://user-images.githubusercontent.com/5395649/46774810-22395980-ccb9-11e8-8f1a-535769d657ec.png)

# %% [markdown]
# # Loading the Model from the Model Catalog

# %%
import os 
import warnings
warnings.filterwarnings('ignore')
import logging
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.ERROR)
import tensorflow as tf 
tf.logging.set_verbosity(tf.logging.ERROR)
import pickle as pkl 
import pandas as pd 
import numpy as np 
import json 
import requests 
from json import dumps, dump
import librosa
import IPython.display as ipd

# oci: 
import oci 
from oci.config import from_file
from oci import pagination
import oci.functions as functions
from oci.functions import FunctionsManagementClient, FunctionsInvokeClient

# ads: 
from ads.common.model_artifact import ModelArtifact
from ads.catalog.model import ModelSummaryList, ModelCatalog

# %%
mc = ModelCatalog(compartment_id = os.environ['NB_SESSION_COMPARTMENT_OCID'])

mc.list_models()
# Out:
# [{
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaagmjymomikkyltl4uddkeeujug5o2f4ssa5ifybrxar73pcb5d7ya",
#    "defined_tags": {},
#    "display_name": "xray_cnn_model",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiabr52rarpys6rvcnhfwylmegdhskmje6wtznqn3w6cdvq",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwiabrkuqsxyfqyhu6zki7nldjpzor6zrjhffh7qli2dxpuq",
#    "time_created": "2020-02-11T18:31:49.714000+00:00",
#    "user_name": "wendy.yip@oracle.com"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "my_model",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiary2gkvf45j7kn23f7wpuras2rbt2d4bw7xzzwnpjvyka",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-05T16:59:34.823000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "xray_cnn_model",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiay7e56ss5yb2gnpzib3fkaeg7usegkrpw3d6wh5skxi3q",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T16:56:44.450000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "Hello_2.1Gb",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiapxmjcvg7om7ksmjsy5rymkixmmawyclhfyw4txnbteba",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:34:34.008000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "Hello_1.9Gb",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwial6ofoio4p2rwdz5uaerzk323kxnpc37n5r5x74t4vlpa",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:30:40.932000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "Hello_3.6Gb",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiac4qiial3w6rw6otzyit7iiamigtzcgmm5l26kzzqmdla",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:23:07.320000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "Hello_3.6Gb",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwia3csjvbbdk4ejyirdsbhpouvlij3g3z5ngwaxniv4it2a",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:21:48.593000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "Hello_1.8Gb",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiapobzstjkkp3z46kabbvejr2jsyvh7nff2fnxuggarghq",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:17:40.652000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "Hello",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwia2xmhckgssbb5fkeczr6lk7fjqkmetuu722d2stbfkjpq",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:15:38.316000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "datasciencemodel20200204030124",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiazjrzzwojfkfmxkw4w4waqpb3fubbilgr376t4zg6agja",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:01:24.050000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "datasciencemodel20200204030036",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiasev6yxogzddv3kgwcoow3qidaxyhvcdqcbgji4thmfwq",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T03:00:36.665000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "datasciencemodel20200204025342",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwia3ykwjeli6eskbos3kiwehgqvfomyplfdgt5x6r53by6a",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T02:53:42.955000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "datasciencemodel20200204025233",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwia72hmqk64mfb2ad74eau4aewbwfalruf4iqubvb3grfdq",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T02:52:33.409000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "datasciencemodel20200204023811",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiaa2mck5kgj6afy77rz4o36dzd2rgwcpu4mojxwporflha",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T02:38:11.437000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "datasciencemodel20200204020105",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiadqqvlx2hhzv3hs6nemcgpkgsg24qzz6u6bdz4kurxj3a",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwialvxd2mnvg4ctzn3inhzoc775tvqyzow5drwfgs7dpb2q",
#    "time_created": "2020-02-04T02:01:05.613000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "datasciencemodel20200204015537",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xw

#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwiaxkgwgktdiphvlegn5ft7mhexaisioriru53b63s6bwbq",
#    "time_created": "2019-12-19T01:58:26.371000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "CLV Cohort Q32019",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiarupwsz647hx4sck5u4o55sw5nyzmj4riam3p3bwnapiq",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwiaxkgwgktdiphvlegn5ft7mhexaisioriru53b63s6bwbq",
#    "time_created": "2019-12-19T01:57:56.166000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "CLV Cohort Q22019",
#    "freeform_tags": {},
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiaoehjz6oks7bnxfdeiaifiuforxyfyljy5o3tv6ryt66a",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwiaxkgwgktdiphvlegn5ft7mhexaisioriru53b63s6bwbq",
#    "time_created": "2019-12-19T01:57:30.900000+00:00",
#    "user_name": "jr_local"
#  }, {
#    "compartment_id": "ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq",
#    "created_by": "ocid1.user.oc1..aaaaaaaabfrlcbiyvjmjvgh3ns6trdyoewxytqywwta3yqmy3ah3fa3uw76q",
#    "defined_tags": {},
#    "display_name": "CLV Cohort Q12019",
#    "freeform_tags": {
#      "20_80_F1": "0.92",
#      "MSE": "0.94",
#      "RMSE": "0.89"
#    },
#    "id": "ocid1.datasciencemodel.oc1.iad.amaaaaaanif7xwiaqgitqmpky4i2bwaykaikxlcg2zv2hzu4544b3ptbdf3a",
#    "lifecycle_state": "ACTIVE",
#    "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaanif7xwiaxkgwgktdiphvlegn5ft7mhexaisioriru53b63s6bwbq",
#    "time_created": "2019-12-19T01:55:07.120000+00:00",
#    "user_name": "jr_local"
#  }]

# %%
path_to_my_loaded_model = '/home/datascience/block_storage/models/tmp'
mc.download_model(mc.list_models()[0].id, path_to_my_loaded_model, force_overwrite=True)
# Out:
#                 <div style="padding: 7px;
#                             border-radius: 4px;
#                             background-color: #d4ecd9;
#                             margin_bottom: 5px;">
#                     <p><b>TIP:</b><br>&nbsp;&nbsp;+&nbsp;Call <code>install_requirements()</code> on the returned <code>ModelArtifact</code> instance to install the required dependencies for this model artifact.<br>&nbsp;&nbsp;+&nbsp;Any function defined in <code>score.py</code> can be directly invoked on the returned <code>ModelArtifact</code> instance</p>
#                 </div>
# Artifact directory: /home/datascience/block_storage/models/tmp
# Contains: ['__init__.py', 'ds-runtime.yaml', 'score.py', 'ds-requirements.txt', '.model-ignore', 'model.pkl', 'fn-model', 'fn-model/model-fn.pkl', 'fn-model/func.yaml', 'fn-model/func.py', 'fn-model/scorefn.py', 'fn-model/requirements.txt']

# %%
model_artifact = ModelArtifact(path_to_my_loaded_model)
model_artifact.reload()
model3 = model_artifact.model

# %% [markdown]
# We're going to load some of this audio data

# %%
df = pkl.load(open('../data/processed_data.pkl','rb'))

# %%
X_test = df[df['sample'] == "testing"]['mfcc'].values
Y_test = df[df['sample'] == "testing"]['y_hot'].values
Xtest = np.asarray([ sub.reshape(20,32,1) for sub in X_test ])

# %%
model3.predict(Xtest[0].reshape(1,20,32,1))
# Out:
# array([[0.29468557, 0.2082487 , 0.49706563]], dtype=float32)

# %% [markdown]
# # Testing Model Deployment through Oracle Functions
#
# We will load pre-recorded wave files and invoke the Function through the OCI Python SDK.
#
# Note that the docker image has already been build and and push to the OCI Registry. We also deployed a Function to Oracle Functions. Here we will walk you through the steps needed to invoke that Function.
#
# You do not need to modify the cell below. We gave your user group access to the Functions deployed in the compartment listed below.

# %%
# Lets specify the location of our OCI configuration file: 
oci_config = from_file("/home/datascience/block_storage/.oci/config")

# Lets specify the compartment OCID, and the application + function names: 
compartment_id = 'ocid1.compartment.oc1..aaaaaaaafl3avkal72rrwuy4m5rumpwh7r4axejjwq5hvwjy4h4uoyi7kzyq' 
app_name = 'machine-learning-models'
fn_name = 'speech-commands'

# %%
fn_management_client = FunctionsManagementClient(oci_config)

# %%
app_result = pagination.list_call_get_all_results(
        fn_management_client.list_applications,
        compartment_id,
        display_name=app_name
    )

# %%
app_result.data[0].id
# Out:
# 'ocid1.fnapp.oc1.iad.aaaaaaaaaewqny5oyfxtr5qnsojz2d3lwlw4mdqulnzvivlldvgm6ar7fzda'

# %%
fn_result = pagination.list_call_get_all_results(
        fn_management_client.list_functions,
        app_result.data[0].id,
        display_name=fn_name
    )

# %%
fn_result.data[0].id
# Out:
# 'ocid1.fnfunc.oc1.iad.aaaaaaaaacj6vrtwlzz2gl3eylhgxq5xrq23adeti2quvhrdrl2zkpbtkj2a'

# %% [markdown]
# In the cell below we are creating an instance of the `FunctionsInvokeClient` object. This instance object will target our deployed Function

# %%
invoke_client = FunctionsInvokeClient(oci_config, service_endpoint=fn_result.data[0].invoke_endpoint)

# %% [markdown]
# Let's pass an audio waveform to our function object.
#
# Note the audio clip waveform is converted to a json string object before being passed to the Function.

# %%
# directory where some sample wave files are located: 
sample_data_dir = '../data/'

# filenames 
files = ['6b81fead_nohash_0.wav',
         'ff2b842e_nohash_2.wav',
         'ccb1266b_nohash_1.wav']

# %% [markdown]
# Let's play these audio clips

# %%
ipd.Audio(sample_data_dir+files[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(sample_data_dir+files[1])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(sample_data_dir+files[2])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
waveform0, _ = librosa.load(sample_data_dir+files[0], mono=True, sr=None)
waveform1, _ = librosa.load(sample_data_dir+files[1], mono=True, sr=None)
waveform2, _ = librosa.load(sample_data_dir+files[2], mono=True, sr=None)

# %%
# %%time

resp = invoke_client.invoke_function(fn_result.data[0].id, 
                                     invoke_function_body=json.dumps({"input": waveform0.tolist()}))
print(resp.data.text)
# Out:
# {"what-you-said-was": "cat"}
# CPU times: user 42.4 ms, sys: 1.38 ms, total: 43.8 ms
# Wall time: 97.2 ms

# %%
# %%time

resp = invoke_client.invoke_function(fn_result.data[0].id, 
                                     invoke_function_body=json.dumps({"input": waveform1.tolist()}))
print(resp.data.text)
# Out:
# {"what-you-said-was": "right"}
# CPU times: user 36.2 ms, sys: 2.28 ms, total: 38.5 ms
# Wall time: 451 ms

# %%
# %%time

resp = invoke_client.invoke_function(fn_result.data[0].id, 
                                     invoke_function_body=json.dumps({"input": waveform2.tolist()}))
print(resp.data.text)
# Out:
# {"what-you-said-was": "eight"}
# CPU times: user 27.4 ms, sys: 1.3 ms, total: 28.7 ms
# Wall time: 89.6 ms
